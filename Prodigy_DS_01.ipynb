# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import pandas as pd
df = pd.read_csv('/content/API_SP.POP.TOTL_DS2_en_csv_v2_144171.csv', sep=',', header=1)
df.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Last Updated Date  \
# ...

# %%
print(df.columns)
# Out:
# Index(['Last Updated Date', '2024-05-30', 'Unnamed: 2'], dtype='object')

# %%
np.random.seed(0)
ages = np.random.randint(18, 70, size=100)
plt.figure(figsize=(10,6))
plt.hist(ages, bins=10, color = 'red', edgecolor = 'black', alpha = 0.5)
plt.title('Distribution of ages in a population!')
plt.xlabel('Ages')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()
